# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/06proyecto/clase_46.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 46 – Mentoría de Proyectos y Resolución de Problemas Técnicos
#
# ## 1. Contexto
# - Continuación del trabajo en proyectos prácticos de los estudiantes.
# - Se retomaron los proyectos presentados en clases anteriores (Sebastián, Kiara, Alicia).
# - El profesor apoyó principalmente en temas técnicos de:
#   - Entrenamiento de modelos en **Colab**.
#   - Manejo de datasets grandes.
#   - Uso de entornos virtuales.
#   - Solución de errores en demos y despliegues web.
#
# ---
#
# ## 2. Proyecto de Sebastián – Diagnóstico de Cáncer
# - **Avances:**
#   - Siguió entrenando el modelo con un dataset grande (~200k imágenes).
#   - Implementó cambios en el código para mejorar el manejo de clases y balancear pesos.
# - **Problemas:**
#   - Colab en versión gratuita limita la cantidad de datos cargados (ej. 17.000 de 35.000 imágenes).
# - **Recomendaciones:**
#   - Usar **RoboFlow** para subir datasets y entrenar más eficientemente.
#   - Trabajar con subsets de datos para evitar bloqueos.
#   - Considerar optimización de hiperparámetros (epochs, learning rate).
# - **Próximos pasos:**
#   - Continuar entrenamiento y experimentar con configuraciones diferentes.
#
# ---
#
# ## 3. Proyecto de Alicia – Predicción de Trazos
# - **Avances:**
#   - Arregló problema de reinicios automáticos de **Live Server** al guardar imágenes.
#   - Configuró excepciones en settings para evitar reinicio al actualizar outputs.
#   - Demo en HTML/Canvas ya muestra los trazos generados (aunque aún con lógica simple en JavaScript).
# - **Problemas:**
#   - Velocidad en la visualización de trazos (demora más de lo esperado).
#   - Uso de varios colores sin unificación en la demo.
#   - Algunos errores en el uso de `return` en funciones que cortaban la ejecución del script.
# - **Recomendaciones:**
#   - Simplificar la lógica en Canvas.
#   - Avanzar en la integración del modelo real en lugar de sólo trazos matemáticos.
#   - Explorar servicios como **Netlify** o **Vercel** para publicar la demo y compartirla.
# - **Próximos pasos:**
#   - Conectar el frontend con el modelo de predicción.
#   - Refinar la interfaz y los tiempos de ejecución.
#
# ---
#
# ## 4. Proyecto de Kiara – Detección de Humo y Fuego
# - **Avances:**
#   - Sigue subiendo imágenes a RoboFlow (ya más de 14.000).
#   - Algunas cargadas sin labels por errores de configuración.
# - **Problemas:**
#   - Carga muy lenta y pesada en Colab.
#   - Colab gratuito limita el número de archivos procesados.
# - **Recomendaciones:**
#   - Subir imágenes directamente con labels preexistentes.
#   - Evitar anotar a mano si el dataset ya tiene segmentación hecha.
#   - Trabajar por lotes para no sobrecargar la subida.
# - **Próximos pasos:**
#   - Completar la subida del dataset a RoboFlow.
#   - Avanzar hacia entrenamiento del modelo con un set más controlado.
#
# ---
#
# ## 5. Notas Generales de la Sesión
# - El profesor explicó el uso de **entornos virtuales** para evitar conflictos de versiones.
# - Se revisó cómo publicar prototipos web con herramientas gratuitas (Netlify, Vercel).
# - Se enfatizó:
#   - No complicarse en exceso con la primera versión del proyecto.
#   - Empezar con algo simple y mejorarlo en iteraciones.
# - Se abrió espacio para que los estudiantes trabajaran y consultaran en paralelo.
# - Próxima meta: que los proyectos tengan **prototipos funcionales** en septiembre.
