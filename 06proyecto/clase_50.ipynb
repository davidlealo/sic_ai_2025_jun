# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/06proyecto/clase_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 50 – Cierre del Curso y Preparación de Presentaciones Finales
#
# ## 1. Contexto
# - Clase de cierre del programa **Samsung Innovation Campus 2025** (50 sesiones en total, desde el 27 de junio al 28 de agosto).
# - Objetivo: dejar todo listo para las **presentaciones finales** de proyectos.
# - Se revisaron avances puntuales de estudiantes y se definió la organización de las presentaciones.
#
# ---
#
# ## 2. Avances de Proyectos
#
# ### Proyecto de Sebastián – Diagnóstico de Cáncer
# - **Avances:**
#   - Logró entrenar modelos adicionales con mejores resultados (accuracy 0.86 aprox.).
#   - Integra distintos modelos en su app con un **desplegable** para que el usuario elija.
#   - Aplicación desarrollada en **Streamlit** y Visual Studio Code, desplegada en la nube.
# - **Problemas:**
#   - Lentitud de entrenamiento (hasta 12h en Colab).
# - **Próximos pasos:**
#   - Ajustar interfaz final (selector de modelos).
#   - Preparar demo para la presentación.
#
# ### Proyecto de Leandro – Sistema de Recomendación de Empleos
# - **Avances:**
#   - Implementó **web scraping** para recolectar ofertas laborales.
#   - Limpieza de datos y creación de corpus con títulos, empresas, requerimientos y condiciones.
#   - Vectorización y cálculo de similitudes con **cosine similarity**.
#   - Prototipo que recomienda los 10 empleos más afines al perfil ingresado.
# - **Problemas:**
#   - Algunos enlaces no redirigen bien al detalle de la oferta.
# - **Próximos pasos:**
#   - Corregir links.
#   - Montar una **app con Gradio** para pruebas rápidas.
#   - Ampliar scraping a otros portales (ej. Indeed).
#
# ### Otros Proyectos Revisados
# - **Grupo de Lengua de Señas (Hugo, Franco, Ariel, Eduardo, Nicolás y Paula):**
#   - Ya tienen prototipo en Django desplegado.
#   - Ajustaron la presentación con estilo visual de **Samsung**.
# - **Kiara (detección de humo y fuego):**
#   - Pendiente mejorar el preprocesamiento de imágenes y métricas de validación.
# - **Alicia (predicción de trazos):**
#   - Proyecto en etapa final, prototipo ya probado en Canvas.
#
# ---
#
# ## 3. Organización de Presentaciones
# - Se definió que las presentaciones se harán en **dos jornadas**:
#   - **Miércoles y viernes** de la próxima semana.
# - Cada presentación: aprox. 15 minutos por grupo.
# - Estructura esperada:
#   1. Problema que buscan resolver.
#   2. Explicación de la solución.
#   3. Técnicas de ML/IA utilizadas.
#   4. Prototipo en ejecución (demo en vivo o video).
#   5. Impacto esperado del proyecto.
# - Se invitará a **invitados externos**:
#   - Representantes de Samsung.
#   - Colaboradores como **Barbarita** (mentora invitada).
#
# ---
#
# ## 4. Evaluación Final del Curso
# - **Criterios:**
#   - Asistencia mínima 90% (todos cumplen).
#   - Resultados de **quizzes** de módulos 2 en adelante.
#   - Proyecto final (evaluación del prototipo).
#   - Test final (Google Form) antes del 18 de septiembre.
#   - Encuesta **NPS** para evaluar el curso (anónima, vista solo por Samsung).
# - **Adicional:**
#   - Se sugiere actualizar **perfil de LinkedIn** como buena práctica (no obligatorio).
#   - Participación en iniciativas externas como **Buena Onda Talks** y becas de **Platzi**.
#
# ---
#
# ## 5. Cierre de la Clase
# - Se destacó el **gran avance de todos los proyectos**: ya están en etapa de prototipo funcional.
# - Próxima semana:
#   - **Lunes** → ensayo breve de presentaciones.
#   - **Miércoles y viernes** → presentaciones finales con invitados.
# - Mensaje final: la presentación es la oportunidad de mostrar todo lo aprendido y causar una **buena impresión a Samsung y a los invitados**.
#
# ---
