# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/06proyecto/clase_51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 51 – Ensayo de Presentaciones y Últimos Ajustes
#
# ## 1. Contexto
# - Clase posterior al cierre formal del curso.
# - Objetivo: revisar **presentaciones finales** de los proyectos y dar retroalimentación práctica.
# - Se resolvieron dudas sobre estructura, referencias y despliegue de demos.
#
# ---
#
# ## 2. Proyecto de Felipe – Atención en el Aula con Visión Computacional
# - **Avances:**
#   - Uso de cámaras y modelo YOLO para detectar posturas de estudiantes en sala de clases.
#   - Generación de *key points* para evaluar **niveles de atención** (alta, media, baja).
#   - Implementó un sistema de penalización y bonificación según postura (recta, encorvada, uso de celular, etc.).
# - **Retroalimentación:**
#   - El profesor sugirió conectar con investigaciones previas (ej. proyecto de la Fundación Bill & Melinda Gates).
#   - Enfatizar el **cambio tecnológico**: antes era invasivo, ahora con IA se generan métricas automáticas y privadas.
#   - Posibilidad de ampliar con métodos no supervisados (clustering de roles en clase).
# - **Próximos pasos:**
#   - Ajustar validación científica con especialistas o encuestas.
#   - En la presentación: mostrar resultados actuales y la proyección a futuro.
#
# ---
#
# ## 3. Proyecto de Sebastián – Diagnóstico de Cáncer
# - **Avances:**
#   - Preparó presentación con estructura clara: problema, objetivo, modelo CNN con Keras, resultados y proyecciones.
#   - Interfaz en **Streamlit** con selector de modelos.
# - **Retroalimentación:**
#   - Incluir referencias de papers en el **cuerpo de las diapositivas** y no solo al final.
#   - Mostrar capturas del prototipo funcionando.
# - **Próximos pasos:**
#   - Ensayar demo en vivo desde Streamlit.
#   - Simplificar slides y mantener claridad visual con template de Samsung.
#
# ---
#
# ## 4. Proyecto de Alicia – Predicción de Trazos
# - **Avances:**
#   - Presentación estructurada en motivación, dataset, workflow, modelos probados (RNN y Transformer) y resultados.
#   - Mostró ejemplos de outputs con 50–60 épocas de entrenamiento.
# - **Retroalimentación:**
#   - Comparar con referentes (ej. evolución de ChatGPT con mayor cantidad de datos).
#   - Destacar la **innovación**: uso de Transformer en lugar de RNN.
#   - Mostrar mejoras progresivas y explicar limitaciones (capacidad computacional).
# - **Próximos pasos:**
#   - Usar ejemplos visuales en la presentación para mostrar potencial futuro.
#   - Subrayar impacto en apoyo a artistas principiantes.
#
# ---
#
# ## 5. Organización de Presentaciones
# - Presentaciones finales: **miércoles 3 de septiembre** (intención de concentrar todos ese día).
# - Formato esperado:
#   1. Problema y motivación.
#   2. Objetivo del proyecto.
#   3. Dataset y metodología.
#   4. Modelos y código (ejemplos clave, no todo).
#   5. Resultados y prototipo.
#   6. Impacto esperado y proyección a futuro.
# - Invitados confirmados:
#   - Representantes de **Samsung**.
#   - **Barbarita** como mentora externa.
#
# ---
#
# ## 6. Cierre de la Sesión
# - Se aclaró que no es obligatorio mostrar todo el código, basta con fragmentos representativos.
# - Recomendación: enfocarse en contar una historia clara y visual.
# - Se sugirió preparar capturas por si falla la demo en vivo.
# - El profesor reforzó que todos los proyectos están en condiciones de presentarse con confianza.
#
# ---
