# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/06proyecto/clase_47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 47 – Avances de Proyectos y Mentoría Técnica
#
# ## 1. Contexto
# - Se mantuvo la dinámica de las últimas sesiones: cada estudiante muestra avances y recibe apoyo para superar dificultades técnicas.
# - La clase se centró en tres grandes líneas de proyectos:
#   - Sebastián con diagnóstico de cáncer mediante imágenes.
#   - Alicia con predicción de trazos/dibujos.
#   - Un nuevo proyecto de detección de objetos aplicado a reciclaje.
#   - Además, se comentaron nuevas ideas (como web scraping para recomendaciones de empleos).
#
# ---
#
# ## 2. Proyecto de Sebastián – Diagnóstico de Cáncer
# - **Avances:**
#   - Entrenó un modelo con **checkpoints** para no perder el trabajo al reiniciar Colab.
#   - Probó configuraciones de 15, 20 y 30 épocas.
# - **Problemas:**
#   - Colab se reinicia tras 12 horas → se pierde parte del entrenamiento.
#   - Dataset demasiado grande (~200k imágenes).
# - **Recomendaciones:**
#   - Usar **Colab Pro** o **máquinas virtuales en la nube** (Google Cloud, AWS, Azure).
#   - Entrenar en su propio computador (i7, 16GB RAM) si es estable.
#   - Usar **RoboFlow** para datasets más pequeños y bien anotados.
#   - Considerar reducción del dataset o usar versiones preprocesadas.
# - **Próximos pasos:**
#   - Comparar entrenamientos en distintos entornos.
#   - Revisar métricas específicas de visión como **mAP (Mean Average Precision)**.
#
# ---
#
# ## 3. Proyecto de Alicia – Predicción de Trazos
# - **Avances:**
#   - Adaptó el dataset **QuickDraw** a formatos procesables (JSON, NPZ).
#   - Implementó data augmentation (rotación, escalado, ruido, espejado).
#   - Probó un **modelo Transformer**, pero la accuracy bajaba con los epochs.
# - **Problemas:**
#   - Entrenamientos demasiado lentos en Colab (5h para 3 épocas).
#   - Accuracy descendente al aumentar épocas → posible sobreajuste o mal procesamiento de datos.
#   - Dudas sobre si la augmentación con **ruido** estaba afectando negativamente.
# - **Recomendaciones:**
#   - Probar también con **RNN o SketchRNN** como comparación.
#   - Considerar que los datos de QuickDraw son simples → agregar ruido puede empeorar.
#   - Explorar **Hugging Face** como plataforma para alojar y probar el modelo.
# - **Próximos pasos:**
#   - Ajustar parámetros y simplificar arquitectura.
#   - Comparar rendimiento entre Transformer y RNN.
#   - Subir prototipo a Hugging Face para pruebas rápidas.
#
# ---
#
# ## 4. Proyecto de Reciclaje – Detección de Objetos
# - **Avances:**
#   - Objetivo: detectar y clasificar basura (plástico, vidrio, cartón, metal).
#   - Usó dataset de **RoboFlow** con categorías predefinidas.
#   - Implementó YOLO preentrenado (basado en **COCO dataset**).
#   - Probó demo con video → clasificación básica funcionando.
# - **Problemas:**
#   - Integración con la webcam en Colab no funcionaba bien.
# - **Recomendaciones:**
#   - Usar scripts para habilitar cámara en Colab.
#   - Seguir ajustando YOLOv8 con dataset de reciclaje.
# - **Próximos pasos:**
#   - Integrar modelo en prototipo de robot con cámara.
#   - Mejorar precisión del modelo con más datos de reciclaje.
#
# ---
#
# ## 5. Nueva Idea – Leandro (Recomendación de empleos con Web Scraping)
# - **Propuesta:**
#   - Scraping de sitios de empleo → recolectar datos de anuncios.
#   - Extraer requisitos de experiencia, herramientas, educación.
#   - Construir un **sistema de recomendación** para sugerir empleos a usuarios.
# - **Sugerencias del profesor:**
#   - Implementar como sistema de recomendación con librerías como **Surprise** (collaborative filtering).
#   - Probar también enfoques basados en contenido (palabras clave de las ofertas).
#   - Posible análisis de sueldos según descripciones.
#
# ---
#
# ## 6. Otros Comentarios
# - Se habló sobre datasets de **cámaras de seguridad** aplicables a proyectos de monitoreo de clases y análisis de atención.
# - El profesor compartió recursos de datasets abiertos para seguridad.
# - Recordatorio: presentaciones tentativamente el **jueves siguiente**, con flexibilidad para extender plazos si es necesario.
#
# ---
#
# ## 7. Conclusiones
# - Sebastián debe resolver la infraestructura de entrenamiento (Colab vs. nube vs. local).
# - Alicia avanza en su Transformer, pero necesita comparar con modelos más simples.
# - Proyecto de reciclaje ya tiene prototipo funcional con YOLO.
# - Se suman nuevas ideas de scraping y recomendación laboral.
# - Próximos días: consolidar avances para llegar a **prototipos funcionales** en las presentaciones.
