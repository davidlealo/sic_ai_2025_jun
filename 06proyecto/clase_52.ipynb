# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/06proyecto/clase_52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 52 – Reunión Previa a las Presentaciones Finales
#
# ## 1. Contexto
# - Clase corta y de preparación inmediata para el **día de las presentaciones**.
# - El profesor revisó dudas pendientes y entregó detalles de **organización y logística**.
# - Se enfatizó que los proyectos están en proceso continuo, pero este es el momento de **mostrar resultados y prototipos**.
#
# ---
#
# ## 2. Invitados Confirmados
# - Representantes estratégicos que estarán presentes:
#   - **Samsung** (equipo de innovación).
#   - **Gloria Moya** (Corfo).
#   - **Wilson Page** (Microsoft for Startups para toda América).
#   - **Barbarita Lara** (mentora externa, innovación tecnológica).
#   - Pablo Flare (profesor invitado en algunas sesiones).
# - Objetivo: dar relevancia y visibilidad al trabajo de los estudiantes frente a aliados clave.
#
# ---
#
# ## 3. Presentaciones
# - Cada grupo tendrá **15 minutos de exposición** + **5 minutos de preguntas**.
# - Flexibilidad: algunos grupos pueden requerir más o menos tiempo, lo importante es que todos presenten.
# - Sugerencias:
#   - Enfocarse en **contar la historia** del proyecto.
#   - Mostrar resultados actuales y **proyecciones futuras**.
#   - Incluir capturas o demos funcionales.
#   - Pueden mostrar fragmentos de código, pero no es necesario entrar en detalles técnicos extensos.
# - Se compartieron ejemplos de presentaciones del año anterior (Big Data e Inteligencia Artificial) como referencia.
#
# ---
#
# ## 4. Informe Final
# - Además de la presentación, se debe entregar un **informe breve**:
#   - No necesita ser extenso.
#   - Puede ser sintético (1–2 párrafos por sección).
#   - Debe incluir: motivación, objetivo, metodología, resultados y conclusiones.
# - Plazo sugerido: **18 de septiembre** como fecha ideal para enviar, para que el profesor tenga tiempo de revisarlo y dar feedback antes de la entrega oficial.
#
# ---
#
# ## 5. Cierre de la Sesión
# - Mensaje clave: *“Los proyectos nunca están totalmente terminados, pero mañana es el momento de presentarlos.”*
# - Recomendación: disfrutar la instancia como una oportunidad de lucirse y mostrar lo aprendido.
# - Última cita: la convocatoria es a las **18:30 horas**, con inicio de presentaciones alrededor de las 19:00.
# - Se confirmó que quedará un **video registro** de la jornada, como ocurrió con las generaciones anteriores.
#
# ---
