# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/06proyecto/clase_48.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 48 – Revisión de Proyectos y Problemas Técnicos
#
# ## 1. Contexto
# - Sesión de seguimiento de proyectos de los estudiantes.
# - El foco estuvo en **resolver problemas técnicos de entrenamiento y despliegue**.
# - Se revisaron los avances de tres estudiantes principales:
#   - Fernando (detección de patentes).
#   - Alicia (predicción de trazos con Transformers).
#   - Sebastián (modelo de imágenes médicas).
#
# ---
#
# ## 2. Proyecto de Fernando – Detección de Patentes
# - **Avances:**
#   - Entrenamiento de modelo en **Kaggle** en lugar de Colab, con tiempos más rápidos (10–15 minutos para 30 épocas).
#   - Implementación de mejoras: batch normalization, learning rate scheduler.
#   - Ajustó clases en el dataset con scripts (problemas de etiquetas mal generadas).
# - **Problemas:**
#   - Algunos errores en reconocimiento de patentes, especialmente con guiones.
#   - Limitaciones en Colab (tiempos, cuotas de uso).
# - **Recomendaciones:**
#   - Centrarse en que el modelo no se sobreajuste.
#   - Implementar versión demo en **Gradio**.
#   - Probar alternativas en Kaggle y Google Cloud.
# - **Próximos pasos:**
#   - Llegar a un accuracy cercano al 90%.
#   - Avanzar en integración a un prototipo de aplicación.
#
# ---
#
# ## 3. Proyecto de Alicia – Predicción de Trazos
# - **Avances:**
#   - Simplificó el modelo, logrando un **accuracy de 89%** en identificación de trazos.
#   - Entrena un segundo modelo con varias categorías (perro, gato, casa, etc.).
# - **Problemas:**
#   - Entrenamientos largos y riesgo de sobreajuste.
# - **Recomendaciones:**
#   - Mantener modelos simples mientras se prueban resultados.
#   - Ampliar categorías después de comprobar rendimiento.
# - **Próximos pasos:**
#   - Terminar entrenamiento del modelo multicategoría.
#   - Probar inferencia y visualización de resultados.
#
# ---
#
# ## 4. Proyecto de Sebastián – Imágenes Médicas
# - **Avances:**
#   - Logró configurar entrenamiento en Kaggle.
#   - Ya dispone de un prototipo que alcanza buenos resultados en accuracy y validación.
# - **Problemas:**
#   - Limitaciones de hardware y tiempo en Colab (sesiones cortas).
#   - Errores al intentar correr todo el dataset completo.
# - **Recomendaciones:**
#   - Continuar con Kaggle como alternativa a Colab.
#   - Optimizar recursos y reducir datasets si es necesario.
# - **Próximos pasos:**
#   - Consolidar el prototipo.
#   - Avanzar hacia implementación en demo para presentación.
#
# ---
#
# ## 5. Notas Generales
# - Se exploraron alternativas a Colab:
#   - **Kaggle Notebooks** (40 horas semanales gratis, GPU T4).
#   - **Google Cloud Notebooks** (con créditos iniciales).
#   - Otras opciones: MyBinder, Gradient.
# - Importancia de:
#   - Guardar checkpoints.
#   - Evitar sobreajuste.
#   - Priorizar la implementación y demos funcionales.
# - El profesor destacó que, para el tiempo disponible, el foco debe estar en **mostrar prototipos implementados más que perfeccionar métricas**.
#
# ---
