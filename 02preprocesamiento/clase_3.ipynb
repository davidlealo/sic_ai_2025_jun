# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/Clase3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Concatenación de listas en Python
#
# Cuando quieres unir dos listas en Python, puedes usar el operador `+`, pero **esto no modifica las listas originales**, sino que crea una nueva lista con los elementos de ambas.
#
# ```python
# a = [1, 2, 3]
# b = [4, 5, 6]
#
# c = a + b  # Concatenación: crea una nueva lista
# print(c)   # [1, 2, 3, 4, 5, 6]

# %%
a = [1, 2, 3]
b = [4, 5, 6]

c = a + b  # Concatenación: crea una nueva lista
print(c)   # [1, 2, 3, 4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Operaciones con arrays en NumPy
#
# En cambio, si usamos **NumPy**, al realizar el mismo tipo de operación (`+`), se **sumará elemento a elemento**, es decir, se suma el valor del índice `i` del primer array con el valor del índice `i` del segundo array.
#
# Este comportamiento se llama **operación vectorizada** y es mucho más eficiente que usar bucles.
#
# ```python
# import numpy as np
#
# a = np.array([1, 2, 3])
# b = np.array([4, 5, 6])
#
# c = a + b
# print(c)  # [5 7 9]

# %%
import pandas as pd

# %%
# importar archivo /content/20250512_Asistencia_ABRIL_2025_20250507_WEB.csv
df = pd.read_csv('20250512_Asistencia_ABRIL_2025_20250507_WEB.csv', sep=';')

# %%
df
# Out:
#         AGNO  MES_ESCOLAR   RBD  DGV_RBD                  NOM_RBD  \
# 0       2025            4     1        9  LICEO POLITECNICO ARICA
# 1       2025            4     1        9  LICEO POLITECNICO ARICA
# 2       2025            4     1        9  LICEO POLITECNICO ARICA
# 3       2025            4     1        9  LICEO POLITECNICO ARICA
# 4       2025            4     1        9  LICEO POLITECNICO ARICA
# ...      ...          ...   ...      ...                      ...
# 922798  2025            4  5010        5        ESCUELA METODISTA
# 922799  2025            4  5010        5        ESCUELA METODISTA
# 922800  2025            4  5010        5        ESCUELA METODISTA
# 922801  2025            4  5010        5        ESCUELA METODISTA
# 922802  2025            4  5010        5        ESCUELA METODISTA
#
#         COD_REG_RBD NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  ...  \
# 0                15           AYP          151        15101       ARICA  ...
# 1                15           AYP          151        15101       ARICA  ...
# 2                15           AYP          151        15101       ARICA  ...
# 3                15           AYP          151        15101       ARICA  ...
# 4                15           AYP          151        15101       ARICA  ...
# ...             ...           ...          ...          ...         ...  ...
# 922798            8          BBIO           81         8102     CORONEL  ...
# 922799            8          BBIO           81         8102     CORONEL  ...
# 922800            8          BBIO           81         8102     CORONEL  ...
# 922801            8          BBIO           81         8102     CORONEL  ...
# 922802            8          BBIO           81         8102      CORONE  ...
#
#         COD_GRADO LET_CUR        MRUN GEN_ALU  FEC_NAC_ALU  COD_COM_ALU  \
# 0             3.0       A   5981391.0     2.0     197304.0      15101.0
# 1             3.0       A   8523172.0     1.0     198309.0      15101.0
# 2             3.0       A   9715496.0     2.0     199909.0      15101.0
# 3             3.0       A  17833318.0     2.0     196406.0      15101.0
# 4             3.0       A  21536575.0     2.0     199305.0      15101.0
# ...           ...     ...         ...     ...          ...          ...
# 922798        5.0       B  18754491.0     2.0     201411.0       8102.0
# 922799        5.0       B  18949561.0     1.0     201404.0       8102.0
# 922800        5.0       B  20168278.0     2.0     201412.0       8102.0
# 922801        5.0       B  20367654.0     2.0     201407.0       8102.0
# 922802        NaN     NaN         NaN     NaN          NaN          NaN
#
#         NOM_COM_ALU  DIAS_ASISTIDOS  DIAS_TRABAJADOS      ASIS_PROMEDIO
# 0             ARICA             0.0             21.0                  0
# 1             ARICA            19.0             21.0   ,904761904761905
# 2             ARICA            19.0             21.0   ,904761904761905
# 3             ARICA            16.0             21.0   ,761904761904762
# 4             ARICA             1.0             21.0  ,0476190476190476
# ...             ...             ...              ...                ...
# 922798      CORONEL            17.0             21.0    ,80952380952381
# 922799      CORONEL            20.0             21.0   ,952380952380952
# 922800      CORONEL            21.0             21.0                  1
# 922801      CORONEL            21.0             21.0                  1
# 922802          NaN             NaN              NaN                NaN
#
# [922803 rows x 28 columns]

# %% [markdown]
# PROXIMA CLASE DESDE SLIDE
# 152
