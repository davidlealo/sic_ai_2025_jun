# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2025_jun/blob/main/02preprocesamiento/clase_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# pd.merge(df_left, df_right, on='NAME')
# pd.merge(df_left, df_right, left_on='NAME', right_on='NAME', how='inner')
# pd.merge(df_left, df_right, left_on='NAME', right_on='NAME', how='left')
# pd.merge(df_left, df_right, left_on='NAME', right_on='NAME', how='right')
# pd.merge(df_left, df_right, left_on='NAME', right_on='NAME', how='outer')

# %%
df1 = pd.DataFrame({'a':['a0', 'a1', 'a2', 'a3'],
                    'b':['b0', 'b1', 'b2', 'b3'],
                    'c':['c0', 'c1', 'c2', 'c3']},
                  index=[0, 1, 2, 3])

# %%
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2 = pd.DataFrame({'a':['a2', 'a3', 'a4', 'a5'],
                    'b':['b2', 'b3', 'b4', 'b5'],
                    'c':['c2', 'c3', 'c4', 'c5'],
                    'd':['d2', 'd3', 'd4', 'd5']},
                  index=[2, 3, 4, 5])

# %%
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
pd.concat([df1, df2])
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5

# %%
pd.concat([df1, df2], join='inner')

# Cambié el ¡outer que está por defecto por inner en el join https://pandas.pydata.org/docs/reference/api/pandas.concat.html
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5

# %%
pd.concat([df1, df2], axis=1)
# Out:
#      a    b    c    a    b    c    d
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5

# %%
pd.concat([df1, df2], axis=1, join='inner')
# Out:
#     a   b   c   a   b   c   d
# 2  a2  b2  c2  a2  b2  c2  d2
# 3  a3  b3  c3  a3  b3  c3  d3

# %% [markdown]
# Vimmos los dos primeros grupos (nos faltó el código eso sí) La meta es terminar mañana la unidad 3 para comenzar con ML después del break
